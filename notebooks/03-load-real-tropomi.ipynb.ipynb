# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

print("Loading REAL TROPOMI methane data...")

# Load all files
import glob
files = glob.glob('/home/vittoria/methane-justice/data/tropomi/200301_202312-C3S-L3_XCH4-GHG_PRODUCTS-MERGED-MERGED-OBS4MIPS-MERGED-v4.6.nc')
print(f"Found {len(files)} files")

# Load first file to inspect
ds = xr.open_dataset(files[0])
# print("Dataset structure:")
# print(ds)
print(f"\nData shape: {ds.dims}")
print(f"Variables: {list(ds.data_vars)}")
print(f"Coordinates: {list(ds.coords)}")

# Check if it's global
print(f"\nLatitude range: {ds.coords['lat'].values.min()} to {ds.coords['lat'].values.max()}")
print(f"Longitude range: {ds.coords['lon'].values.min()} to {ds.coords['lon'].values.max()}")
# Out:
# Loading REAL TROPOMI methane data...
# Found 1 files
# Dataset structure:
# <xarray.Dataset>
# Dimensions:                  (time: 252, bnds: 2, lat: 36, lon: 72, pressure: 10)
# Coordinates:
#   * time                     (time) datetime64[ns] 2003-01-16T12:00:00 ... 20...
#   * lat                      (lat) float64 -87.5 -82.5 -77.5 ... 77.5 82.5 87.5
#   * lon                      (lon) float64 -177.5 -172.5 -167.5 ... 172.5 177.5
# Dimensions without coordinates: bnds, pressure
# Data variables:
#     time_bnds                (time, bnds) datetime64[ns] ...
#     lat_bnds                 (lat, bnds) float64 ...
#     lon_bnds                 (lon, bnds) float64 ...
#     pre                      (pressure) float64 ...
#     pre_bnds                 (pressure, bnds) float64 ...
#     land_fraction            (lat, lon) float64 ...
#     xch4                     (time, lat, lon) float32 ...
#     xch4_nobs                (time, lat, lon) float64 ...
# ...
